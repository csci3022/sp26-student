# %% [markdown]
# # Lesson 2: Pandas Bootcamp Part 1 - updated for class on 1/17/24
#
# [Acknowledgments Page](https://ds100.org/fa23/acks/)

# %%
import numpy as np
import pandas as pd
import plotly.express as px

# %% [markdown]
# ### Loading Elections Data Into a DataFrame:
#
# Panda's [read_csv function](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html) is one of the most versatile and useful functions for managing data.
#
# **Practice:  Load the elections data**

# %%
elections = pd.read_csv("data/elections.csv")

# %% [markdown]
# ### `DataFrame` attributes: `index`, `columns`

# %%
elections.index

# %%
elections.columns

# %% [markdown]
# The `Index` column can be set to the default list of integers by calling `reset_index()` on a `DataFrame`.

# %% [markdown]
# # Extraction:
#
# One of the most basic tasks for manipulating a DataFrame is to extract rows and columns of interest.

# %% [markdown]
# ### Label-Based Extraction Using`loc`
#
# `loc` selects items by row and column *label*.
#
# `df.loc[row_labels, column_labels]`
#
# We describe "labels" as the bolded text at the top and left of a DataFrame.
#
#
#
#
# Arguments to `.loc` can be:
# 1. A row label and column label
# 2. A list.
# 3. A slice (syntax is inclusive of the right-hand side of the slice).

# %%
# Here's how we can select all rows and just the Year and Party columns from the elections dataframe.
# Note we use the ellipsis (:) in the first entry because we want to select all rows

elections.loc[:,["Year","Party"]]
# Out:
#      Year                  Party
# 0    2020             Democratic
# 1    2020             Republican
# 2    2020            Libertarian
# 3    2020                  Green
# 4    2016           Constitution
# ..    ...                    ...
# 177  1832           Anti-Masonic
# 178  1828             Democratic
# 179  1828    National Republican
# 180  1824  Democratic-Republican
# 181  1824  Democratic-Republican
#
# [182 rows x 2 columns]

# %%
# Selection by a list

elections.loc[[87, 25, 179], ["Year", "Candidate", "Result"]]

# %%
# Selection by a list and a slice of columns
elections.loc[[87, 25, 179], "Popular vote":"%"]

# %%
# Extracting all rows using a colon
elections.loc[:, ["Year", "Candidate", "Result"]]

# %%
# Extracting all columns using a colon
elections.loc[[87, 25, 179], :]

# %%
# Selection by a list and a single-column label
elections.loc[[87, 25, 179], "Popular vote"]

# %%
# Note that if we pass "Popular vote" in a list, the output will be a DataFrame
elections.loc[[87, 25, 179], ["Popular vote"]]

# %%
# Selection by a row label and a column label
elections.loc[0, "Candidate"]

# %% [markdown]
# #### Integer-Based Extraction Using `iloc`

# %% [markdown]
# `iloc` selects items by row and column *integer* position.
#
# Arguments to `.iloc` can be:
# 1. A list.
# 2. A slice (syntax is exclusive of the right hand side of the slice).
# 3. A single value.

# %%
# Select the rows at positions 1, 2, and 3.
# Select the columns at positions 0, 1, and 2.
# Remember that Python indexing begins at position 0!
elections.iloc[[1, 2, 3], [0, 1, 2]]

# %%
# Index-based extraction using a list of rows and a slice of column indices
elections.iloc[[1, 2, 3], 0:3]

# %%
# Selecting all rows using a colon
elections.iloc[:, 0:3]

# %%
elections.iloc[[1, 2, 3], 1]

# %%
# Extracting the value at row 0 and the second column
elections.iloc[0,1]

# %% [markdown]
# #### Context-dependent Extraction using `[]`

# %% [markdown]
# We could technically do anything we want using `loc` or `iloc`. However, in practice, the `[]` operator is often used instead to yield more concise code.
#
# `[]` is a bit trickier to understand than `loc` or `iloc`, but it achieves essentially the same functionality. The difference is that `[]` is *context-dependent*.
#
# `[]` only takes one argument, which may be:
# 1. A slice of row integers.
# 2. A list of column labels.
# 3. A single column label.

# %% [markdown]
# If we provide a slice of row numbers, [start:stop], we get all rows with those integer positions.  While the element at the start index is included, the stop index is not included, so that the number of elements in the result is stop - start.

# %%
elections[3:7]

# %% [markdown]
# If we provide a list of column names, we get the listed columns.

# %%
elections[["Year", "Candidate", "Result"]]

# %% [markdown]
# And if we provide a single column name we get back just that column, stored as a `Series`.

# %%
elections["Candidate"]

# %% [markdown]
# ### Multi-indexed DataFrames
#
# You can also define multiple indexes for the same DataFrame.  This is useful when you need more than one column to specify the granularity of the data.
# For example, if we wanted to use both `Year` and `Party` as our indices we would do this as follows:

# %%
elections_multindex = elections.set_index(["Year","Party"])

# %%
elections_multindex.head()
# Out:
#                                     Candidate  Popular vote Result          %
# Year Party
# 1824 Democratic-Republican     Andrew Jackson        151271   loss  57.210122
#      Democratic-Republican  John Quincy Adams        113142    win  42.789878
# 1828 Democratic                Andrew Jackson        642806    win  56.203927
#      National Republican    John Quincy Adams        500897   loss  43.796073
# 1832 Democratic                Andrew Jackson        702735    win  54.574789

# %% [markdown]
# ### Accessing Data in Multi-indexed DataFrames:
#
# Now, to access data we can use `.loc` where the first entry is a tuple: (year, party):

# %%
elections_multindex.loc[(1828,"Democratic"),:]
# Out:
# /tmp/ipykernel_737/2237968762.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   elections_multindex.loc[(1828,"Democratic"),:]
#                       Candidate  Popular vote Result          %
# Year Party
# 1828 Democratic  Andrew Jackson        642806    win  56.203927

# %% [markdown]
# Notice, we got a warning above.  This just means that your index is not sorted. pandas depends on the index being sorted (in this case, lexicographically, since we are dealing with string values) for optimal search and retrieval. A quick fix would be to sort your DataFrame in advance using DataFrame.sort_index. This is especially desirable from a performance standpoint if you plan on doing multiple such queries in tandem:

# %%
elections_multindex = elections_multindex.sort_index()
elections_multindex.loc[(1828,"Democratic"),:]
# Out:
#                       Candidate  Popular vote Result          %
# Year Party
# 1828 Democratic  Andrew Jackson        642806    win  56.203927

# %% [markdown]
# ## Setting a New Index:

# %% [markdown]
# Suppose we want to know how many elections Andrew Jackson ran in.
#
# **Practice:** Set the elections index to be Candidate.

# %%
elections = elections.set_index("Candidate")
elections
# Out:
#                         Year                  Party  Popular vote Result  \
# Candidate
# Kamala Harris           2024             Democratic      75019230   loss
# Donald Trump            2024             Republican      77303568    win
# Jill Stein              2024                  Green        861155   loss
# Robert F. Kennedy Jr.   2024            Independent        756383   loss
# Chase Oliver            2024            Libertarian        650130   loss
# ...                      ...                    ...           ...    ...
# William Wirt            1832           Anti-Masonic        100715   loss
# Andrew Jackson          1828             Democratic        642806    win
# John Quincy Adams       1828    National Republican        500897   loss
# Andrew Jackson          1824  Democratic-Republican        151271   loss
# John Quincy Adams       1824  Democratic-Republican        113142    win
#
#                                 %
# Candidate
# Kamala Harris           48.340000
# Donald Trump            49.810000
# Jill Stein               0.600000
# Robert F. Kennedy Jr.    0.600000
# Chase Oliver             0.400000
# ...                           ...
# William Wirt             7.821583
# Andrew Jackson          56.203927
# John Quincy Adams       43.796073
# Andrew Jackson          57.210122
# John Quincy Adams       42.789878
#
# [189 rows x 5 columns]

# %% [markdown]
# **Practice:Select only the rows when Andrew Jackson ran in an election**

# %%
elections.loc["Andrew Jackson"]
# Out:
#                 Year                  Party  Popular vote Result          %
# Candidate
# Andrew Jackson  1832             Democratic        702735    win  54.574789
# Andrew Jackson  1828             Democratic        642806    win  56.203927
# Andrew Jackson  1824  Democratic-Republican        151271   loss  57.210122

# %% [markdown]
# **Practice:  Reset the index (to the default integer indices)**

# %%
elections = elections.reset_index()

# %% [markdown]
# **Practice:  Create a new dataframe that is just the first 10 rows of the elections dataframe**

# %%
elections_first_10 = elections.head(10)
elections_first_10
# Out:
#    Year               Candidate                               Party  \
# 0  2024           Kamala Harris                          Democratic
# 1  2024            Donald Trump                          Republican
# 2  2024              Jill Stein                               Green
# 3  2024  Robert F. Kennedy Jr.                          Independent
# 4  2024            Chase Oliver                         Libertarian
# 5  2024      Claudia De La Cruz  Party for Socialism and Liberation
# 6  2024             Cornel West                         Independent
# 7  2020            Joseph Biden                          Democratic
# 8  2020            Donald Trump                          Republican
# 9  2020            Jo Jorgensen                         Libertarian
#
#    Popular vote Result          %
# 0      75019230   loss  48.340000
# 1      77303568    win  49.810000
# 2        861155   loss   0.600000
# 3        756383   loss   0.600000
# 4        650130   loss   0.400000
# 5        165095   loss   0.100000
# 6         81041   loss   0.100000
# 7      81268924    win  51.311515
# 8      74216154   loss  46.858542
# 9       1865724   loss   1.177979

# %% [markdown]
# ## Boolean Arrays

# %%
a = np.array([True, False, True, False, True, False, False, False, False, False])

# %%
# What happens when you sum a boolean array?
a.sum()
# Out:
# 3

# %%
# What happens if you put a boolean array as an input to the .loc or [] operator?

# %%
elections_first_10[a]
# Out:
#        Candidate  Year        Party  Popular vote Result      %
# 0  Kamala Harris  2024   Democratic      75019230   loss  48.34
# 2     Jill Stein  2024        Green        861155   loss   0.60
# 4   Chase Oliver  2024  Libertarian        650130   loss   0.40

# %%
elections_first_10[[True, False, True, True, False, False, True, False, True, False]]
# Out:
#    Year               Candidate        Party  Popular vote Result          %
# 0  2024           Kamala Harris   Democratic      75019230   loss  48.340000
# 2  2024              Jill Stein        Green        861155   loss   0.600000
# 3  2024  Robert F. Kennedy Jr.   Independent        756383   loss   0.600000
# 6  2024             Cornel West  Independent         81041   loss   0.100000
# 8  2020            Donald Trump   Republican      74216154   loss  46.858542

# %% [markdown]
# ## Conditional Selection

# %% [markdown]
# By passing in a sequence (list, array, or `Series`) of boolean values, we can extract a subset of the rows in a `DataFrame`. We will keep *only* the rows that correspond to a boolean value of `True`.
#
#
# **Practice:  Use Conditional Selection to Extract all rows from the elections DataFrame where the percentage of popular votes was greater than 50%**

# %%
# First, use a logical condition to generate a boolean Series:
# (another name for this logical operator is a "Boolean Mask")
logical_operator = elections["%"]>50

logical_operator
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 184    False
# 185     True
# 186    False
# 187     True
# 188    False
# Name: %, Length: 189, dtype: bool

# %%
# Then, use this boolean array to filter the DataFrame
elections[logical_operator]
# Out:
#                   Candidate  Year                  Party  Popular vote Result  \
# 7              Joseph Biden  2020             Democratic      81268924    win
# 17             Barack Obama  2012             Democratic      65915795    win
# 21             Barack Obama  2008             Democratic      69498516    win
# 28           George W. Bush  2004             Republican      62040610    win
# 50        George H. W. Bush  1988             Republican      48886597    win
# 55            Ronald Reagan  1984             Republican      54455472    win
# 61            Ronald Reagan  1980             Republican      43903230    win
# 64             Jimmy Carter  1976             Democratic      40831881    win
# 70            Richard Nixon  1972             Republican      47168710    win
# 75           Lyndon Johnson  1964             Democratic      43127041    win
# 76             John Kennedy  1960             Democratic      34220984    win
# 79        Dwight Eisenhower  1956             Republican      35579180    win
# 82        Dwight Eisenhower  1952             Republican      34075529    win
# 90       Franklin Roosevelt  1944             Democratic      25612916    win
# 92       Franklin Roosevelt  1940             Democratic      27313945    win
# 96       Franklin Roosevelt  1936             Democratic      27752648    win
# 99       Franklin Roosevelt  1932             Democratic      22821277    win
# 104          Herbert Hoover  1928             Republican      21427123    win
# 106         Calvin Coolidge  1924             Republican      15723789    win
# 113          Warren Harding  1920             Republican      16144093    win
# 126            William Taft  1908             Republican       7678335    win
# 130      Theodore Roosevelt  1904             Republican       7630557    win
# 134        William McKinley  1900             Republican       7228864    win
# 138        William McKinley  1896             Republican       7112138    win
# 155        Samuel J. Tilden  1876             Democratic       4288546   loss
# 157           Ulysses Grant  1872             Republican       3597439    win
# 159           Ulysses Grant  1868             Republican       3013790    win
# 160         Abraham Lincoln  1864         National Union       2211317    win
# 169         Franklin Pierce  1852             Democratic       1605943    win
# 176              James Polk  1844             Democratic       1339570    win
# 178  William Henry Harrison  1840                   Whig       1275583    win
# 180        Martin Van Buren  1836             Democratic        763291    win
# 182          Andrew Jackson  1832             Democratic        702735    win
# 185          Andrew Jackson  1828             Democratic        642806    win
# 187          Andrew Jackson  1824  Democratic-Republican        151271   loss
#
#              %
# 7    51.311515
# 17   51.258484
# 21   53.023510
# 28   50.771824
# 50   53.518845
# 55   59.023326
# 61   50.897944
# 64   50.271900
# 70   60.907806
# 75   61.344703
# 76   50.082561
# 79   57.650654
# 82   55.325173
# 90   53.773801
# 92   54.871202
# 96   60.978107
# 99   57.672125
# 104  58.368524
# 106  54.329113
# 113  60.574501
# 126  52.013300
# 130  56.562787
# 134  52.342640
# 138  51.213817
# 155  51.528376
# 157  55.928594
# 159  52.665305
# 160  54.951512
# 169  51.013168
# 176  50.749477
# 178  53.051213
# 180  52.272472
# 182  54.574789
# 185  56.203927
# 187  57.210122

# %% [markdown]
# ### Bitwise Operators

# %% [markdown]
# To filter on multiple conditions, we combine boolean operators using **bitwise comparisons**.
#
# Symbol | Usage      | Meaning
# ------ | ---------- | -------------------------------------
# ~    | ~p       | Returns negation of p
# &#124; | p &#124; q | p OR q
# &    | p & q    | p AND q
# ^  | p ^ q | p XOR q (exclusive or)

# %% [markdown]
# **Practice: Extract all rows from the elections DataFrame when Andrew Jackson was elected president**

# %%
# OPTION 1: 
elections.loc[(elections["Candidate"]=="Andrew Jackson") & (elections["Result"]=="win")]
# Out:
#      Year       Candidate       Party  Popular vote Result          %
# 182  1832  Andrew Jackson  Democratic        702735    win  54.574789
# 185  1828  Andrew Jackson  Democratic        642806    win  56.203927

# %%
# OPTION 2:
elections= elections.set_index(["Candidate", "Result"])
elections.loc[("Andrew Jackson", "win"),:]
# Out:
#                                Year                  Party  Popular vote  \
# Candidate              Result
# Kamala Harris          loss    2024             Democratic      75019230
# Donald Trump           win     2024             Republican      77303568
# Jill Stein             loss    2024                  Green        861155
# Robert F. Kennedy Jr.  loss    2024            Independent        756383
# Chase Oliver           loss    2024            Libertarian        650130
# ...                             ...                    ...           ...
# William Wirt           loss    1832           Anti-Masonic        100715
# Andrew Jackson         win     1828             Democratic        642806
# John Quincy Adams      loss    1828    National Republican        500897
# Andrew Jackson         loss    1824  Democratic-Republican        151271
# John Quincy Adams      win     1824  Democratic-Republican        113142
#
#                                        %
# Candidate              Result
# Kamala Harris          loss    48.340000
# Donald Trump           win     49.810000
# Jill Stein             loss     0.600000
# Robert F. Kennedy Jr.  loss     0.600000
# Chase Oliver           loss     0.400000
# ...                                  ...
# William Wirt           loss     7.821583
# Andrew Jackson         win     56.203927
# John Quincy Adams      loss    43.796073
# Andrew Jackson         loss    57.210122
# John Quincy Adams      win     42.789878
#
# [189 rows x 4 columns]

# %%
# reset index for further examples below

elections = elections.reset_index()

# %% [markdown]
# ### Another Selection Option:  Query
#
# Read the documentation for query:
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.query.html
#
# Use query to select all rows where the Candiate was John Quincy Adams OR the Popular Vote was greater than 70,000,000

# %%
elections.query("Candidate=='John Quincy Adams' | `Popular vote` > 70000000")
# Out:
#      Year          Candidate                  Party  Popular vote Result  \
# 0    2024      Kamala Harris             Democratic      75019230   loss
# 1    2024       Donald Trump             Republican      77303568    win
# 7    2020       Joseph Biden             Democratic      81268924    win
# 8    2020       Donald Trump             Republican      74216154   loss
# 186  1828  John Quincy Adams    National Republican        500897   loss
# 188  1824  John Quincy Adams  Democratic-Republican        113142    win
#
#              %
# 0    48.340000
# 1    49.810000
# 7    51.311515
# 8    46.858542
# 186  43.796073
# 188  42.789878

# %% [markdown]
# **Practice: Use Query to Extract all rows from the elections DataFrame when Andrew Jackson was elected president**

# %%
elections.query("Candidate == 'Andrew Jackson' & Result == 'win'")
# Out:
#      Year       Candidate       Party  Popular vote Result          %  \
# 182  1832  Andrew Jackson  Democratic        702735    win  54.574789
# 185  1828  Andrew Jackson  Democratic        642806    win  56.203927
#
#      frac_voters
# 182     0.545748
# 185     0.562039

# %% [markdown]
# **Practice: Use Query to Extract all rows from the elections DataFrame where the percentage of popular votes was greater than 50 AND the candidate lost**

# %%
elections.query("Result == 'loss' & `%`>50")
# Out:
#      Year         Candidate                  Party  Popular vote Result  \
# 155  1876  Samuel J. Tilden             Democratic       4288546   loss
# 187  1824    Andrew Jackson  Democratic-Republican        151271   loss
#
#              %  frac_voters
# 155  51.528376     0.515284
# 187  57.210122     0.572101

# %% [markdown]
# ## Adding, Removing, and Modifying Columns

# %% [markdown]
# ### Adding or Modifying a Column
# To add (or modify an existing) column, use `.assign()`
#
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.assign.html
#
#
# Syntax:
#
# `df = df.assign(new_col_name = new_col_values)`

# %%
# Add a column called frac_voters with the fraction of voters who voted in each election
elections = elections.assign(frac_voters = elections["%"]/100)

elections
# Out:
#      Year               Candidate                  Party  Popular vote Result  \
# 0    2024           Kamala Harris             Democratic      75019230   loss
# 1    2024            Donald Trump             Republican      77303568    win
# 2    2024              Jill Stein                  Green        861155   loss
# 3    2024  Robert F. Kennedy Jr.             Independent        756383   loss
# 4    2024            Chase Oliver            Libertarian        650130   loss
# ..    ...                     ...                    ...           ...    ...
# 184  1832            William Wirt           Anti-Masonic        100715   loss
# 185  1828          Andrew Jackson             Democratic        642806    win
# 186  1828       John Quincy Adams    National Republican        500897   loss
# 187  1824          Andrew Jackson  Democratic-Republican        151271   loss
# 188  1824       John Quincy Adams  Democratic-Republican        113142    win
#
#              %  frac_voters
# 0    48.340000     0.483400
# 1    49.810000     0.498100
# 2     0.600000     0.006000
# 3     0.600000     0.006000
# 4     0.400000     0.004000
# ..         ...          ...
# 184   7.821583     0.078216
# 185  56.203927     0.562039
# 186  43.796073     0.437961
# 187  57.210122     0.572101
# 188  42.789878     0.427899
#
# [189 rows x 7 columns]

# %% [markdown]
# **Practice:  Add a new column to elections called "TotVoters" that gives the total number of people who voted in that particular election**

# %%
elections = elections.assign(TotVoters= elections["Popular vote"]/elections["frac_voters"])

elections
# Out:
#      Year               Candidate                  Party  Popular vote Result  \
# 0    2024           Kamala Harris             Democratic      75019230   loss
# 1    2024            Donald Trump             Republican      77303568    win
# 2    2024              Jill Stein                  Green        861155   loss
# 3    2024  Robert F. Kennedy Jr.             Independent        756383   loss
# 4    2024            Chase Oliver            Libertarian        650130   loss
# ..    ...                     ...                    ...           ...    ...
# 184  1832            William Wirt           Anti-Masonic        100715   loss
# 185  1828          Andrew Jackson             Democratic        642806    win
# 186  1828       John Quincy Adams    National Republican        500897   loss
# 187  1824          Andrew Jackson  Democratic-Republican        151271   loss
# 188  1824       John Quincy Adams  Democratic-Republican        113142    win
#
#              %  frac_voters     TotVoters
# 0    48.340000     0.483400  1.551908e+08
# 1    49.810000     0.498100  1.551969e+08
# 2     0.600000     0.006000  1.435258e+08
# 3     0.600000     0.006000  1.260638e+08
# 4     0.400000     0.004000  1.625325e+08
# ..         ...          ...           ...
# 184   7.821583     0.078216  1.287655e+06
# 185  56.203927     0.562039  1.143703e+06
# 186  43.796073     0.437961  1.143703e+06
# 187  57.210122     0.572101  2.644130e+05
# 188  42.789878     0.427899  2.644130e+05
#
# [189 rows x 8 columns]

# %% [markdown]
# ### Rename a Column Name
# Rename a column using the `.rename()` method.
#
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.rename.html

# %% [markdown]
# Rename "TotVoters to "Total_Voters":

# %%
elections = elections.rename(columns = {"TotVoters": "Total_Voters"})

elections
# Out:
#      Year               Candidate                  Party  Popular vote Result  \
# 0    2024           Kamala Harris             Democratic      75019230   loss
# 1    2024            Donald Trump             Republican      77303568    win
# 2    2024              Jill Stein                  Green        861155   loss
# 3    2024  Robert F. Kennedy Jr.             Independent        756383   loss
# 4    2024            Chase Oliver            Libertarian        650130   loss
# ..    ...                     ...                    ...           ...    ...
# 184  1832            William Wirt           Anti-Masonic        100715   loss
# 185  1828          Andrew Jackson             Democratic        642806    win
# 186  1828       John Quincy Adams    National Republican        500897   loss
# 187  1824          Andrew Jackson  Democratic-Republican        151271   loss
# 188  1824       John Quincy Adams  Democratic-Republican        113142    win
#
#              %  frac_voters  Total_Voters
# 0    48.340000     0.483400  1.551908e+08
# 1    49.810000     0.498100  1.551969e+08
# 2     0.600000     0.006000  1.435258e+08
# 3     0.600000     0.006000  1.260638e+08
# 4     0.400000     0.004000  1.625325e+08
# ..         ...          ...           ...
# 184   7.821583     0.078216  1.287655e+06
# 185  56.203927     0.562039  1.143703e+06
# 186  43.796073     0.437961  1.143703e+06
# 187  57.210122     0.572101  2.644130e+05
# 188  42.789878     0.427899  2.644130e+05
#
# [189 rows x 8 columns]

# %% [markdown]
# ### Delete a Column
# Remove a column using `.drop()`
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop.html

# %% [markdown]
# Drop the columns "frac_voters" and "Total_Voters":

# %%
elections = elections.drop(columns=["frac_voters","Total_Voters"])
elections

# %% [markdown]
# ## Useful Utility Functions

# %% [markdown]
# ### `NumPy`

# %% [markdown]
# `NumPy` functions are compatible with Series objects in `pandas`.

# %%
import numpy as np

np.mean(elections["Popular vote"])
# Out:
# 12715335.111111112

# %%
# Max 

np.max(elections["Popular vote"])
# Out:
# 81268924

# %% [markdown]
# ### Built-In `pandas` Methods
#
# There are many, *many* utility functions built into `pandas`, far more than we can possibly cover in lecture. You are encouraged to explore all the functionality outlined in the `pandas` [documentation](https://pandas.pydata.org/docs/reference/index.html).

# %% [markdown]
# #### Useful Python Functions
#
# `len(series)`
#
# `len(df)`
#
#
#
# #### Useful Series Utility Functions
#
# `series.unique()`
#
# `series.sort_values()`
#
# `series.value_counts()`
#
# `series.isna()`
#
#
#
# #### Useful DataFrame Utility Functions
#
# `df.shape`
#
# `df.info()`
#
# `df.describe()`
#
# `df.sort_values()`
#
# `df.value_counts()`
#
# `df.isna()`

# %% [markdown]
# **Practice:  Run each of the cells below to explore what each of these commonly used functions do.**

# %%
len(elections["Party"])
# Out:
# 189

# %%
len(elections)
# Out:
# 189

# %% [markdown]
# #### Useful Utility Functions for Series (i.e. Individual Columns of DataFrame)

# %%
elections["Party"].unique()
# Out:
# array(['Democratic', 'Republican', 'Green', 'Independent', 'Libertarian',
#        'Party for Socialism and Liberation', 'Constitution', 'Reform',
#        'Taxpayers', 'Natural Law', 'Populist', 'New Alliance', 'Citizens',
#        'American Independent', 'American', "States' Rights",
#        'Progressive', 'Prohibition', 'Socialist', 'Dixiecrat', 'Union',
#        'Communist', 'Farmer–Labor', 'National Democratic', 'Union Labor',
#        'Anti-Monopoly', 'Greenback', 'Liberal Republican',
#        'National Union', 'Constitutional Union', 'Southern Democratic',
#        'Northern Democratic', 'Free Soil', 'Whig', 'National Republican',
#        'Anti-Masonic', 'Democratic-Republican'], dtype=object)

# %%
len(elections["Party"].unique())
# Out:
# 37

# %%
elections["Candidate"].sort_values()
# Out:
# 109          Aaron S. Watkins
# 160           Abraham Lincoln
# 162           Abraham Lincoln
# 78            Adlai Stevenson
# 81            Adlai Stevenson
#                 ...
# 171            Winfield Scott
# 153    Winfield Scott Hancock
# 117            Woodrow Wilson
# 122            Woodrow Wilson
# 174            Zachary Taylor
# Name: Candidate, Length: 189, dtype: object

# %%
elections["Candidate"].sort_values(ascending=False)
# Out:
# 174            Zachary Taylor
# 122            Woodrow Wilson
# 117            Woodrow Wilson
# 153    Winfield Scott Hancock
# 171            Winfield Scott
#                 ...
# 81            Adlai Stevenson
# 78            Adlai Stevenson
# 160           Abraham Lincoln
# 162           Abraham Lincoln
# 109          Aaron S. Watkins
# Name: Candidate, Length: 189, dtype: object

# %%
elections["Candidate"].value_counts()
# Out:
# Candidate
# Norman Thomas             5
# Eugene V. Debs            4
# Ralph Nader               4
# Franklin Roosevelt        4
# William Jennings Bryan    3
#                          ..
# John B. Anderson          1
# Ed Clark                  1
# Barry Commoner            1
# Walter Mondale            1
# Strom Thurmond            1
# Name: count, Length: 137, dtype: int64

# %%
elections["Candidate"].isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 184    False
# 185    False
# 186    False
# 187    False
# 188    False
# Name: Candidate, Length: 189, dtype: bool

# %%
elections[elections["Candidate"].isna()]
# Out:
# Empty DataFrame
# Columns: [Year, Candidate, Party, Popular vote, Result, %, TotVoters, TotVotersPlusYear]
# Index: []

# %%
sum(elections["Candidate"].isna())
# Out:
# 0

# %% [markdown]
# #### Useful Utility Functions for DataFrames

# %%
elections.shape
# Out:
# (189, 8)

# %%
  
elections.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189 entries, 0 to 188
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               189 non-null    int64
#  1   Candidate          189 non-null    object
#  2   Party              189 non-null    object
#  3   Popular vote       189 non-null    int64
#  4   Result             189 non-null    object
#  5   %                  189 non-null    float64
#  6   TotVoters          189 non-null    float64
#  7   TotVotersPlusYear  189 non-null    float64
# dtypes: float64(3), int64(2), object(3)
# memory usage: 11.9+ KB

# %%
elections.describe()
# Out:
#               Year  Popular vote           %     TotVoters  TotVotersPlusYear
# count   189.000000  1.890000e+02  189.000000  1.890000e+02       1.890000e+02
# mean   1937.417989  1.271534e+07   26.981766  5.666689e+07       5.667077e+07
# std      58.508591  1.993289e+07   23.068772  4.905665e+07       4.905676e+07
# min    1824.000000  8.104100e+04    0.098088  2.644130e+05       2.680610e+05
# 25%    1892.000000  3.844310e+05    1.067883  1.204191e+07       1.204570e+07
# 50%    1940.000000  1.457226e+06   37.603628  4.763084e+07       4.763473e+07
# 75%    1992.000000  1.974382e+07   48.340000  9.615227e+07       9.615626e+07
# max    2024.000000  8.126892e+07   61.344703  1.650950e+08       1.650990e+08

# %%
elections.sort_values(by="Year")
# Out:
#      Year               Candidate                  Party  Popular vote Result  \
# 188  1824       John Quincy Adams  Democratic-Republican        113142    win
# 187  1824          Andrew Jackson  Democratic-Republican        151271   loss
# 185  1828          Andrew Jackson             Democratic        642806    win
# 186  1828       John Quincy Adams    National Republican        500897   loss
# 183  1832              Henry Clay    National Republican        484205   loss
# ..    ...                     ...                    ...           ...    ...
# 4    2024            Chase Oliver            Libertarian        650130   loss
# 3    2024  Robert F. Kennedy Jr.             Independent        756383   loss
# 2    2024              Jill Stein                  Green        861155   loss
# 1    2024            Donald Trump             Republican      77303568    win
# 0    2024           Kamala Harris             Democratic      75019230   loss
#
#              %     TotVoters  TotVotersPlusYear
# 188  42.789878  2.644130e+05       2.680610e+05
# 187  57.210122  2.644130e+05       2.680610e+05
# 185  56.203927  1.143703e+06       1.147359e+06
# 186  43.796073  1.143703e+06       1.147359e+06
# 183  37.603628  1.287655e+06       1.291319e+06
# ..         ...           ...                ...
# 4     0.400000  1.625325e+08       1.625365e+08
# 3     0.600000  1.260638e+08       1.260679e+08
# 2     0.600000  1.435258e+08       1.435299e+08
# 1    49.810000  1.551969e+08       1.552009e+08
# 0    48.340000  1.551908e+08       1.551948e+08
#
# [189 rows x 8 columns]

# %%
elections.value_counts()
# Out:
# Year  Candidate               Party                  Popular vote  Result  %          TotVoters     TotVotersPlusYear
# 1824  Andrew Jackson          Democratic-Republican  151271        loss    57.210122  2.644130e+05  2.680610e+05         1
# 1980  John B. Anderson        Independent            5719850       loss    6.631143   8.625738e+07  8.626134e+07         1
# 1976  Eugene McCarthy         Independent            740460        loss    0.911649   8.122208e+07  8.122603e+07         1
#       Gerald Ford             Republican             39148634      loss    48.199499  8.122208e+07  8.122603e+07         1
#       Jimmy Carter            Democratic             40831881      win     50.271900  8.122208e+07  8.122603e+07         1
#                                                                                                                         ..
# 1908  William Taft            Republican             7678335       win     52.013300  1.476225e+07  1.476607e+07         1
# 1912  Eugene V. Debs          Socialist              901551        loss    6.004354   1.501495e+07  1.501878e+07         1
#       Eugene W. Chafin        Prohibition            208156        loss    1.386325   1.501495e+07  1.501878e+07         1
#       Theodore Roosevelt      Progressive            4122721       loss    27.457433  1.501495e+07  1.501878e+07         1
# 2024  Robert F. Kennedy Jr.   Independent            756383        loss    0.600000   1.260638e+08  1.260679e+08         1
# Name: count, Length: 189, dtype: int64

# %%
elections[["Candidate","Party"]].value_counts()
# Out:
# Candidate               Party
# Norman Thomas           Socialist               5
# Franklin Roosevelt      Democratic              4
# Eugene V. Debs          Socialist               4
# William Jennings Bryan  Democratic              3
# Grover Cleveland        Democratic              3
#                                                ..
# Harry Truman            Democratic              1
# Gerald Ford             Republican              1
# George Wallace          American Independent    1
# George McGovern         Democratic              1
# Zachary Taylor          Whig                    1
# Name: count, Length: 146, dtype: int64

# %%
elections.isna()
# Out:
#       Year  Candidate  Party  Popular vote  Result      %  TotVoters  \
# 0    False      False  False         False   False  False      False
# 1    False      False  False         False   False  False      False
# 2    False      False  False         False   False  False      False
# 3    False      False  False         False   False  False      False
# 4    False      False  False         False   False  False      False
# ..     ...        ...    ...           ...     ...    ...        ...
# 184  False      False  False         False   False  False      False
# 185  False      False  False         False   False  False      False
# 186  False      False  False         False   False  False      False
# 187  False      False  False         False   False  False      False
# 188  False      False  False         False   False  False      False
#
#      TotVotersPlusYear
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False
# ..                 ...
# 184              False
# 185              False
# 186              False
# 187              False
# 188              False
#
# [189 rows x 8 columns]

# %%
elections.isna().sum()
# Out:
# Year                 0
# Candidate            0
# Party                0
# Popular vote         0
# Result               0
# %                    0
# TotVoters            0
# TotVotersPlusYear    0
# dtype: int64
